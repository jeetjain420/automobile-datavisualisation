# %%
def read_auto_data(fileName = "automobile"):
    'Function to load the auto price data set from a .csv file' 
    import pandas as pd
    import numpy as np

    ## Read the .csv file with the pandas read_csv method
    auto_prices = pd.read_csv(r"C:\Users\acer pc\OneDrive\Desktop\visualisation\automobile.csv")
    
    ## Remove rows with missing values, accounting for mising values coded as '?'
    cols = ['price', 'bore', 'stroke', 'horsepower', 'peak-rpm']
    for column in cols:
        auto_prices.loc[auto_prices[column] == '?', column] = np.nan
    auto_prices.dropna(axis = 0, inplace = True)

    ## Convert some columns to numeric values
    for column in cols:
        auto_prices[column] = pd.to_numeric(auto_prices[column])
#    auto_prices[cols] = auto_prices[cols].as_type(int64)
        
    return auto_prices
auto_prices = read_auto_data()

# %%
auto_prices.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
auto_prices.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.794872   98.896410  174.256923   65.886154   53.861538
# std      1.230612    6.132038   12.476443    2.132484    2.396778
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.050000   52.000000
# 50%      1.000000   97.000000  173.200000   65.400000   54.100000
# 75%      2.000000  102.400000  184.050000   66.900000   55.650000
# max      3.000000  120.900000  208.100000   72.000000   59.800000
#
#        curb-weight  engine-size        bore      stroke  compression-ratio  \
# count   195.000000   195.000000  195.000000  195.000000         195.000000
# mean   2559.000000   127.938462    3.329385    3.250308          10.194974
# std     524.715799    41.433916    0.271866    0.314115           4.062109
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(auto_prices['city-mpg'], auto_prices['price'],'ro')

# %%
auto_prices.plot(kind = 'scatter',x = 'city-mpg', y = 'price')

# %%
auto_prices.plot(kind = 'scatter', x= 'curb-weight', y='price')

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize= (6,6))
ax = fig.gca()
auto_prices.plot(kind = 'scatter', x ='city-mpg', y = 'price', ax = ax)
ax.set_title('Scatter plot of price vs MPG')
ax.set_xlabel('City MPG')
ax.set_ylabel('Auto price')
# Out:
# Text(0, 0.5, 'Auto price')

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.gca()
auto_prices.plot(kind = 'scatter', x = 'curb-weight', y = 'price', ax=ax)
ax.set_title('Scatter plot of price vs curb weight')
ax.set_xlabel('Curb Weight')
ax.set_ylabel('Auto Price')
# Out:
# Text(0, 0.5, 'Auto Price')

# %% [markdown]
#  We can see that the curb weight or the total weight of the car without any occupants seems to increase with the price, which means the more expensive a car is the larger is its weight

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.gca()
auto_prices.plot(kind = 'scatter', x = 'city-mpg', y = 'price', ax=ax)
ax.set_title('Scatter plot of price vs miles per gallon')
ax.set_xlabel('City MPG')
ax.set_ylabel('Auto Price')
# Out:
# Text(0, 0.5, 'Auto Price')

# %% [markdown]
# We can see from the plot that the miles per gallon of a car seems to increase with the price

# %%
import pandas as pd
x = list(range(100))
y = [z*z for z in range(100)]
df = pd.DataFrame({'x':x, 'y':y})

# %%
fig = plt.figure(figsize = (10,10))

ax = fig.gca()
df.plot( x ='x', y = 'y', ax=ax)
ax.set_title('Line plot of x^2 vs. x')
ax.set_xlabel('x')
ax.set_ylabel('x^2')
# Out:
# Text(0, 0.5, 'x^2')

# %%
counts = auto_prices['make'].value_counts()
counts
# Out:
# toyota           32
# nissan           18
# honda            13
# mazda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# saab              6
# audi              6
# porsche           4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# isuzu             2
# mercury           1
# Name: make, dtype: int64

# %%
fig = plt.figure(figsize = (6,6))
ax = fig.gca()
counts.plot.bar(ax=ax)
ax.set_title('No. of auto types by make')
ax.set_xlabel('Make')
ax.set_ylabel('No. of autos')
# Out:
# Text(0, 0.5, 'No. of autos')

# %%
fig = plt.figure(figsize = (6,6))

ax = fig.gca()
auto_prices['engine-size'].plot.hist(ax=ax)
ax.set_title('Histogram of auto engine size')
ax.set_xlabel('Engine Size')
ax.set_ylabel('No. of autos')
# Out:
# Text(0, 0.5, 'No. of autos')

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.gca()
auto_prices[['engine-size', 'fuel-type']].boxplot(by = 'fuel-type', ax = ax)
ax.set_title('Box plot')
ax.set_xlabel('Fuel Type')
ax.set_ylabel('Engine Size')
# Out:
# Text(0, 0.5, 'Engine Size')

# %% [markdown]
# After examining the plot we can see that the engine size of diesel cars is slightly larger than the gas cars but there are some outliers present in the gas cars which have a much higher size compared to the maximum size of the diesel cars

# %%
import seaborn as sns
sns.set_style("whitegrid")
sns.kdeplot(auto_prices['engine-size'])

# %%
fig = plt.figure(figsize=(6,6)) # define plot area
ax = fig.gca() # define axis 
sns.set_style("whitegrid")
sns.kdeplot(auto_prices['engine-size'], ax = ax)
ax.set_title('KDE plot of auto engine size') # Give the plot a main title
ax.set_xlabel('Engine Size') # Set text for the x axis
ax.set_ylabel('Density')# Set text for y axis
# Out:
# Text(0, 0.5, 'Density')

# %%
fig = plt.figure(figsize = (7,7))
ax = fig.gca()
sns.set_style("whitegrid")
sns.kdeplot(auto_prices[['engine-size', 'price']], ax = ax, cmap ="Blues")
ax.set_title('KDE Plot')
ax.set_xlabel('Engine Size')
ax.set_ylabel('Price')
# Out:
# D:\Anaconda3\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)
# Text(0, 0.5, 'Price')

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.gca()
sns.set_style("whitegrid")
sns.violinplot(x = 'fuel-type', y = 'engine-size', data = auto_prices, ax=ax)
ax.set_title('Violin plots of auto engine size by fuel type')
ax.set_xlabel('Fuel Type')
ax.set_ylabel('Engine Size')
# Out:
# Text(0, 0.5, 'Engine Size')

# %%
num_cols = ["length", "curb-weight", "engine-size", "horsepower", "city-mpg", "price", "fuel-type"] 
sns.pairplot(auto_prices[num_cols], hue='fuel-type', palette="Set2", diag_kind="kde", height=2).map_upper(sns.kdeplot, cmap="Blues_d")
